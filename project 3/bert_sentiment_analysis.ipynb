# %%
from transformers import pipeline
import pandas as pd
import matplotlib.pyplot as plt

# %%
classifier = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
texts = [
    "I love machine learning.",
    "This internship is amazing.",
    "I hate waiting in traffic.",
    "The movie started slowly but eventually became fantastic.",
    "The service was disappointing."
]

results = classifier(texts)

for text, result in zip(texts, results):
    print("Text:", text)
    print(result)
    print()
# Out:
# Text: I love machine learning.
# {'label': 'POSITIVE', 'score': 0.9997828602790833}
#
# Text: This internship is amazing.
# {'label': 'POSITIVE', 'score': 0.9998762607574463}
#
# Text: I hate waiting in traffic.
# {'label': 'NEGATIVE', 'score': 0.9964919686317444}
#
# Text: The movie started slowly but eventually became fantastic.
# {'label': 'POSITIVE', 'score': 0.9994567036628723}
#
# Text: The service was disappointing.
# {'label': 'NEGATIVE', 'score': 0.9997062087059021}

# %%
df = pd.DataFrame(results)
df
# Out:
#       label     score
# 0  POSITIVE  0.999783
# 1  POSITIVE  0.999876
# 2  NEGATIVE  0.996492
# 3  POSITIVE  0.999457
# 4  NEGATIVE  0.999706

# %%
labels = df["label"]
scores = df["score"]

plt.figure(figsize=(8,5))
plt.bar(labels, scores)
plt.xlabel("Sentiment")
plt.ylabel("Confidence Score")
plt.title("Sentiment Confidence")
plt.show()

# %%
df["label"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)
plt.title("Sentiment Distribution")
plt.ylabel("")
plt.show()
